# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Table-of-Contents" data-toc-modified-id="Table-of-Contents-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Table of Contents</a></span></li><li><span><a href="#Графики-зависимостей" data-toc-modified-id="Графики-зависимостей-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Графики зависимостей</a></span></li><li><span><a href="#Круговые-графики" data-toc-modified-id="Круговые-графики-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Круговые графики</a></span></li><li><span><a href="#Точечные-диаграммы" data-toc-modified-id="Точечные-диаграммы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Точечные диаграммы</a></span></li><li><span><a href="#Гистограммы" data-toc-modified-id="Гистограммы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Гистограммы</a></span></li><li><span><a href="#Подграфики" data-toc-modified-id="Подграфики-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подграфики</a></span></li><li><span><a href="#Зачем-это-нужно?" data-toc-modified-id="Зачем-это-нужно?-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Зачем это нужно?</a></span></li></ul></div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Графики зависимостей
# plt.plot(x, y)

# %%
x = np.linspace(0, 20, 500)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# * `color`: Цвет линии
#
# * `linestyle`: способ соединения точек: толстая линия, прерывистая, её отсутствие
#
# * `linewidth`: Задаем тонкость линии
#
# * `marker`: Что использовать для обозначения точки(круг, квадрат,треугольник, ничего).
#
# * `markersize`: Очевидно.
#
# * `label`: Название для данного графика в легенде.

# %%
x = np.linspace(0, 20, 10000)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, y1, color='gray', linestyle='-', marker='s', markersize=2, label='sinx')
plt.plot(x, y2, color='green', linestyle='--', marker='^', markersize=5, label='sin(x-pi)')
plt.legend()

# %% [markdown]
# plt.bar(left, height)
#
# * `left`: x координата
#
# * `height`: соответствующая высота столбца

# %%
years = np.arange(2012, 2015)
values = [2, 5, 9]
plt.figure()
plt.bar(years, values)
# Out:
# <Container object of 3 artists>

# %% [markdown]
# * `color`: Цвет столба
#
# * `edgecolor`: Цвет края столба
#
# * `width`: Ширина столбика
#
# * `label`: аналогично как с plot

# %%
years = np.arange(2012, 2015)
category1_values = [2, 5, 9]
category2_values = [7, 6, 3]

plt.figure()

plt.bar(years - 0.2,
        category1_values,
        color='blue',
        edgecolor='none',
        width=0.4,
        align='center',
        label='y1')

plt.bar(years + 0.2,
        category2_values,
        color='orange',
        edgecolor='blue',
        width=0.4,
        align='center',
        label='y2')

plt.xticks(years, [str(year) for year in years])

plt.legend()

# %% [markdown]
# # Круговые графики
#
#
# plt.pie(sizes)
#
# * `sizes`:

# %%
counts = [17, 14]

plt.figure(figsize=(5,5))

plt.pie(counts)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9d2c26cb90>,
#   <matplotlib.patches.Wedge at 0x7f9d2c27a5d0>],
#  [<matplotlib.text.Text at 0x7f9d2c27a1d0>,
#   <matplotlib.text.Text at 0x7f9d2c27abd0>])

# %%
counts = [17, 3]

plt.figure(figsize=(4, 4))

plt.pie(counts,
        colors=['blue', 'orange'],
        labels=['Cats', 'Dogs'],
        startangle=90,
        autopct='%1.1f%%')
;
# Out:
# ''

# %% [markdown]
# # Точечные диаграммы
#
# plt.scatter(x,y)

# %%
x = range(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x, y)

# %% [markdown]
# Многие функции данной библиотеки имеют похожие параметры.

# %%
x = np.arange(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x, y, c='red',
            marker='s',
            edgecolor='blue')

# %% [markdown]
# # Гистограммы
#
# plt.hist(x)
# `x`: Массив для которого мы хотим посмотреть распределение

# %%
column_data = np.random.normal(42, 3, 1000000)

plt.figure()

plt.hist(column_data)
# Out:
# (array([  6.00000000e+01,   1.82800000e+03,   2.71030000e+04,
#           1.55934000e+05,   3.57299000e+05,   3.24252000e+05,
#           1.16065000e+05,   1.64960000e+04,   9.43000000e+02,
#           2.00000000e+01]),
#  array([ 27.27634797,  30.2849297 ,  33.29351144,  36.30209318,
#          39.31067491,  42.31925665,  45.32783838,  48.33642012,
#          51.34500186,  54.35358359,  57.36216533]),
#  <a list of 10 Patch objects>)

# %%
column_data = np.random.normal(42, 3, 10000)

plt.figure()

plt.hist(column_data,color='red',
         bins=50,
         normed=True)
# Out:
# (array([ 0.00043094,  0.00021547,  0.00021547,  0.00064641,  0.00086188,
#          0.00107735,  0.00258563,  0.00387845,  0.00624861,  0.00689501,
#          0.01422097,  0.01508284,  0.02068504,  0.02477895,  0.03835351,
#          0.04417118,  0.05386729,  0.06248606,  0.08403298,  0.08834236,
#          0.10127051,  0.10471802,  0.12346383,  0.13380635,  0.13014338,
#          0.12992791,  0.12411024,  0.13143619,  0.10773458,  0.10407161,
#          0.0943755 ,  0.08704954,  0.07455233,  0.05796121,  0.03943086,
#          0.03856898,  0.03081209,  0.02283973,  0.017453  ,  0.01249721,
#          0.0056022 ,  0.00387845,  0.00538673,  0.00129282,  0.00107735,
#          0.00043094,  0.00086188,  0.00043094,  0.00021547,  0.00021547]),
#  array([ 30.34078287,  30.80488639,  31.26898991,  31.73309343,
#          32.19719695,  32.66130047,  33.12540399,  33.58950751,
#          34.05361103,  34.51771455,  34.98181807,  35.44592159,
#          35.91002511,  36.37412863,  36.83823215,  37.30233567,
#          37.76643919,  38.23054271,  38.69464623,  39.15874975,
#          39.62285327,  40.08695679,  40.55106031,  41.01516383,
#          41.47926735,  41.94337087,  42.40747439,  42.87157791,
#          43.33568143,  43.79978495,  44.26388847,  44.72799199,
#          45.19209551,  45.65619903,  46.12030255,  46.58440607,
#          47.04850959,  47.51261311,  47.97671663,  48.44082015,
#          48.90492367,  49.36902719,  49.83313071,  50.29723423,
#          50.76133775,  51.22544127,  51.68954479,  52.15364831,
#          52.61775183,  53.08185535,  53.54595887]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# # Подграфики
#
# Позволяет вам строить несколько отдельных графиков на одном изображении.
#
# subplot(nrows, ncols, plot_number)
#
# * `nrows`: Количество графиков в ряд по вертикали
#
# * `ncols`: Количество графиков в ряд по горизонтали
#
# * `plot_number`: Расположение графика на изображении, отсчет начинается с 1.

# %%
plt.figure()

for i in range(1, 7):
    plt.subplot(3, 2, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# %% [markdown]
# # Зачем это нужно?

# %%
years = np.arange(2010, 2016)

plt.figure()

for category_num in range(1, 17):
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

plt.ylim(10, 18)
plt.xticks(years, [str(year) for year in years])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9d2bb07fd0>,
#   <matplotlib.axis.XTick at 0x7f9d2bb34e10>,
#   <matplotlib.axis.XTick at 0x7f9d2bbead10>,
#   <matplotlib.axis.XTick at 0x7f9d2ba4a6d0>,
#   <matplotlib.axis.XTick at 0x7f9d2ba4add0>,
#   <matplotlib.axis.XTick at 0x7f9d2ba56510>],
#  <a list of 6 Text xticklabel objects>)

# %%
years = np.arange(2010, 2016)

plt.figure(figsize=(10, 10))

for category_num in range(1, 17):
    plt.subplot(4, 4, category_num)
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)
    plt.ylim(10, 18)
    plt.xticks(years, [str(year) for year in years])
    plt.title('Number {}'.format(category_num))
    
plt.tight_layout()
